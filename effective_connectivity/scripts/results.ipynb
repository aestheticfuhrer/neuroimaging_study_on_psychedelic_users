# %%
"""
This script performs data loading, exploration, regression analysis, for effective connectivity in paper "When the psychedelic state’s over: limited evidence for persistent neurophysiological changes in experienced psychedelic users"
"""

from statistical_model import Study
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Define frequency band order (from data_preparation.py)
FREQUENCY_BAND_ORDER = ["delta", "theta", "alpha", "beta", "gamma"]


def plot_pvalue_histogram(ax, results, title):
    """Plot p-value histogram on given axes."""
    n_bins = 40
    
    if results[1] is None or 'p-value (perm)' not in results[1].columns:
        ax.text(0.5, 0.5, 'No p-values available', ha='center', va='center', 
                transform=ax.transAxes, fontsize=14)
        ax.set_title(title, fontsize=14)
        return 0, 0
    
    p_values = results[1]['p-value (perm)'].dropna()
    n_pvalues = len(p_values)
    expected_freq = 1.0 / n_bins
    
    ax.hist(p_values, bins=n_bins, edgecolor='black', alpha=0.7,
            density=False, weights=np.ones(n_pvalues) / n_pvalues)
    ax.axhline(y=expected_freq, color='green', linestyle='-', linewidth=2,
               label=f'Expected under null = {expected_freq:.3f}')
    ax.axvline(x=0.05, color='red', linestyle='--', linewidth=2, label='α = 0.05')
    ax.set_title(title, fontsize=14)
    ax.set_yticklabels([])
    ax.grid(axis='y', alpha=0.3)
    ax.tick_params(axis='x', labelsize=12)
    
    return n_pvalues, np.sum(p_values < 0.05)

# %%
# =============================================================================
# 1. Loading the Data
# =============================================================================
print("=" * 80)
print("1. Loading the Data")
print("=" * 80)

import os
from pathlib import Path
# EC_CACHE points at the directory holding the ~3.4 GB .cdb caches, which are
# not distributed and need not live inside the repository. Without it, the
# location is resolved from the cwd, which works whether the kernel starts in
# effective_connectivity/ or its scripts/ subdirectory.
EC_ROOT = Path(os.environ["EC_CACHE"]) if os.environ.get("EC_CACHE") else (
    Path.cwd().parent if Path.cwd().name == "scripts" else Path.cwd())

study = Study.load(str(EC_ROOT / "study_merged_10000.cdb"))
study2 = Study.load(str(EC_ROOT / "study_unmerged_10000.cdb"))

# Study.load() prints and returns None when the file is missing, which would
# otherwise surface three cells later as a confusing AttributeError on None.
if study is None or study2 is None:
    raise FileNotFoundError(
        f"No study caches under {EC_ROOT}. They are ~3.4 GB and not distributed; "
        "rebuild with effective_connectivity/scripts/data_preparation.py, or set "
        "EC_CACHE to the directory that holds them.")

# %%
# =============================================================================
# 2. Exploring the Data
# =============================================================================
print("\n" + "=" * 80)
print("2. Exploring the Data")
print("=" * 80)

# study holds the merged cache (4620 measurements, one pooled sample);
# study2 holds the unmerged one (9240, cities kept as separate samples).
print("\nMerged study summary:")
study.summary()

print("\nUnmerged study summary:")
study2.summary()
# Out:
# ================================================================================
# 2. Exploring the Data
# ================================================================================
#
# Merged study summary:
# Study summary: 4620 measurements loaded
#
# Nodes by label:
# CEN:
#        L-ITG, L-SFG, L-SUP, L-pSTG, R-IFG, R-ITG, R-SFG, R-SUP, R-pSTG
# DMN:
#        L-ANG, L-IFG, L-PREC, L-aSTG, L-mPFC, R-ANG, R-PREC, R-aSTG, R-mPFC
# SN:
#        L-ACC, L-INS, R-ACC, R-INS
#
# Measurement conditions:
#   bands: alpha, beta, delta, gamma, theta
#   city: merged(Kraków,Warszawa)
#   eyes: eyes closed, eyes open
#
# Samples:
#   Sample ID: merged_sample, Subjects: 107
#
# Permutation Statistics:
#   Original Mean Contrast: 0.0216
#   Original Median Contrast: 0.0196
#   Mean Contrast p-value: 0.2149
#   Median Contrast p-value: 0.2905
#   Mean Contrast 95% CI: [-0.0339, 0.0344]
#   Median Contrast 95% CI: [-0.0360, 0.0372]
#   Number of permutations: 10000
#
# Unmerged study summary:
# Study summary: 9240 measurements loaded
#
# Nodes by label:
# CEN:
#        L-ITG, L-SFG, L-SUP, L-pSTG, R-IFG, R-ITG, R-SFG, R-SUP, R-pSTG
# DMN:
#        L-ANG, L-IFG, L-PREC, L-aSTG, L-mPFC, R-ANG, R-PREC, R-aSTG, R-mPFC
# SN:
#        L-ACC, L-INS, R-ACC, R-INS
#
# Measurement conditions:
#   bands: alpha, beta, delta, gamma, theta
#   city: Kraków, Warszawa
#   eyes: eyes closed, eyes open
#
# Samples:
#   Sample ID: city_Kraków, Subjects: 40
#   Sample ID: city_Warszawa, Subjects: 67
#
# Permutation Statistics:
#   Original Mean Contrast: 0.0229
#   Original Median Contrast: 0.0200
#   Mean Contrast p-value: 0.1882
#   Median Contrast p-value: 0.2647
#   Mean Contrast 95% CI: [-0.0338, 0.0342]
#   Median Contrast 95% CI: [-0.0339, 0.0352]
#   Number of permutations: 10000

# %%
# =============================================================================
# 3. Regression Analysis
# =============================================================================
print("\n" + "=" * 80)
print("3. Regression Analysis")
print("=" * 80)

results_network_only = study.regression(
    "~ network_relation -1",
    add_network_categories=True,
    n_permutations=10000,
    band_order=FREQUENCY_BAND_ORDER
)
print(study.print_apa_format(results_network_only))
# Out:
# ================================================================================
# 3. Regression Analysis
# ================================================================================
# Calculating permutation-based statistics...
# Regression Analysis Results (APA Format)
# ----------------------------------------
# Model: contrast ~ network_relation -1
#
# The regression model explained 0.115 of the variance, F = 74.775, p = 0.131
# Note: p-values are permutation-based (permuted group)
#
# Contrast Statistics:
# Mean Contrast: 0.022, 95% CI [-0.034, 0.034], p = 0.215
# Median Contrast: 0.020, 95% CI [-0.036, 0.037], p = 0.290
#
# Regression Coefficients:
# Parameter            Estimate   SE         t          p
# -------------------- ---------- ---------- ---------- ----------
# network_relation[CEN→CEN] 0.012      0.024      3.127      0.655      [-0.036, 0.059]     , q = 0.655
# network_relation[CEN→DMN] 0.070      0.034      19.734     0.036   *  [0.004, 0.136]      , q = 0.324
# network_relation[CEN→SN] 0.078      0.049      14.709     0.107      [-0.018, 0.173]     , q = 0.474
# network_relation[DMN→CEN] -0.030     0.024      -8.568     0.236      [-0.077, 0.017]     , q = 0.474
# network_relation[DMN→DMN] 0.026      0.018      7.078      0.164      [-0.009, 0.062]     , q = 0.474
# network_relation[DMN→SN] 0.032      0.035      6.027      0.393      [-0.036, 0.100]     , q = 0.590
# network_relation[SN→CEN] -0.023     0.041      -4.301     0.614      [-0.104, 0.058]     , q = 0.655
# network_relation[SN→DMN] 0.016      0.032      3.039      0.643      [-0.047, 0.079]     , q = 0.655
# network_relation[SN→SN] 0.027      0.023      2.935      0.263      [-0.018, 0.071]     , q = 0.474
#
# Significance codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Note: q is the Benjamini-Hochberg corrected p-value over this model's 9 coefficients (the Intercept is excluded from the family). 0 of 9 terms have q < 0.05.
#
# Note: All p-values, standard errors, and confidence intervals are permutation-based (permuted group).

# %%
# =============================================================================
# 4. Regression Analysis: interactions
# =============================================================================
print("\n" + "=" * 80)
print("4. Regression Analysis: interactions")
print("=" * 80)

results_network_bands = study.regression(
    "~ network_relation:bands -1",
    add_network_categories=True,
    n_permutations=10000,
    band_order=FREQUENCY_BAND_ORDER
)
print(study.print_apa_format(results_network_bands))
# Out:
# ================================================================================
# 4. Regression Analysis: interactions
# ================================================================================
# Calculating permutation-based statistics...
# Regression Analysis Results (APA Format)
# ----------------------------------------
# Model: contrast ~ network_relation:bands -1
#
# The regression model explained 0.162 of the variance, F = 20.028, p = 0.196
# Note: p-values are permutation-based (permuted group)
#
# Contrast Statistics:
# Mean Contrast: 0.022, 95% CI [-0.034, 0.034], p = 0.215
# Median Contrast: 0.020, 95% CI [-0.036, 0.037], p = 0.290
#
# Regression Coefficients:
# Parameter            Estimate   SE         t          p
# -------------------- ---------- ---------- ---------- ----------
# network_relation[CEN→CEN] × bands[delta] -0.011     0.026      -1.400     0.681      [-0.062, 0.039]     , q = 0.855
# network_relation[CEN→DMN] × bands[delta] 0.029      0.021      3.767      0.198      [-0.013, 0.071]     , q = 0.595
# network_relation[CEN→SN] × bands[delta] 0.057      0.028      4.892      0.054   .  [0.001, 0.112]      , q = 0.590
# network_relation[DMN→CEN] × bands[delta] -0.053     0.038      -6.939     0.172      [-0.128, 0.021]     , q = 0.595
# network_relation[DMN→DMN] × bands[delta] 0.003      0.025      0.385      0.905      [-0.046, 0.053]     , q = 0.947
# network_relation[DMN→SN] × bands[delta] 0.023      0.025      1.952      0.396      [-0.027, 0.072]     , q = 0.810
# network_relation[SN→CEN] × bands[delta] -0.031     0.056      -2.687     0.608      [-0.140, 0.078]     , q = 0.843
# network_relation[SN→DMN] × bands[delta] -0.028     0.046      -2.408     0.579      [-0.117, 0.062]     , q = 0.843
# network_relation[SN→SN] × bands[delta] -0.005     0.036      -0.263     0.891      [-0.076, 0.065]     , q = 0.947
# network_relation[CEN→CEN] × bands[theta] 0.010      0.041      1.273      0.824      [-0.070, 0.091]     , q = 0.947
# network_relation[CEN→DMN] × bands[theta] 0.066      0.047      8.629      0.171      [-0.026, 0.159]     , q = 0.595
# network_relation[CEN→SN] × bands[theta] 0.083      0.060      7.219      0.182      [-0.034, 0.201]     , q = 0.595
# network_relation[DMN→CEN] × bands[theta] -0.030     0.031      -3.852     0.359      [-0.090, 0.030]     , q = 0.808
# network_relation[DMN→DMN] × bands[theta] 0.014      0.030      1.744      0.659      [-0.044, 0.072]     , q = 0.855
# network_relation[DMN→SN] × bands[theta] 0.036      0.046      3.113      0.468      [-0.054, 0.126]     , q = 0.831
# network_relation[SN→CEN] × bands[theta] -0.016     0.037      -1.367     0.684      [-0.088, 0.056]     , q = 0.855
# network_relation[SN→DMN] × bands[theta] 0.021      0.031      1.806      0.528      [-0.041, 0.082]     , q = 0.831
# network_relation[SN→SN] × bands[theta] 0.047      0.032      2.345      0.166      [-0.016, 0.110]     , q = 0.595
# network_relation[CEN→CEN] × bands[alpha] 0.037      0.045      4.534      0.441      [-0.051, 0.125]     , q = 0.831
# network_relation[CEN→DMN] × bands[alpha] 0.105      0.048      13.660     0.029   *  [0.012, 0.198]      , q = 0.565
# network_relation[CEN→SN] × bands[alpha] 0.093      0.053      8.063      0.081   .  [-0.011, 0.197]     , q = 0.590
# network_relation[DMN→CEN] × bands[alpha] 0.016      0.040      2.130      0.704      [-0.062, 0.095]     , q = 0.857
# network_relation[DMN→DMN] × bands[alpha] 0.067      0.036      8.227      0.078   .  [-0.004, 0.139]     , q = 0.590
# network_relation[DMN→SN] × bands[alpha] 0.061      0.040      5.285      0.149      [-0.018, 0.140]     , q = 0.595
# network_relation[SN→CEN] × bands[alpha] -0.007     0.053      -0.618     0.895      [-0.111, 0.096]     , q = 0.947
# network_relation[SN→DMN] × bands[alpha] 0.051      0.046      4.425      0.299      [-0.040, 0.142]     , q = 0.747
# network_relation[SN→SN] × bands[alpha] 0.026      0.037      1.317      0.504      [-0.047, 0.100]     , q = 0.831
# network_relation[CEN→CEN] × bands[beta] 0.019      0.035      2.288      0.618      [-0.049, 0.087]     , q = 0.843
# network_relation[CEN→DMN] × bands[beta] 0.088      0.043      11.472     0.038   *  [0.004, 0.173]      , q = 0.565
# network_relation[CEN→SN] × bands[beta] 0.097      0.058      8.383      0.092   .  [-0.016, 0.210]     , q = 0.590
# network_relation[DMN→CEN] × bands[beta] -0.017     0.031      -2.215     0.604      [-0.078, 0.044]     , q = 0.843
# network_relation[DMN→DMN] × bands[beta] 0.032      0.026      3.933      0.242      [-0.019, 0.083]     , q = 0.674
# network_relation[DMN→SN] × bands[beta] 0.027      0.041      2.376      0.535      [-0.053, 0.108]     , q = 0.831
# network_relation[SN→CEN] × bands[beta] -0.004     0.046      -0.309     0.941      [-0.094, 0.087]     , q = 0.955
# network_relation[SN→DMN] × bands[beta] 0.038      0.036      3.290      0.316      [-0.032, 0.108]     , q = 0.747
# network_relation[SN→SN] × bands[beta] 0.043      0.035      2.134      0.255      [-0.026, 0.111]     , q = 0.674
# network_relation[CEN→CEN] × bands[gamma] 0.004      0.028      0.462      0.895      [-0.051, 0.059]     , q = 0.947
# network_relation[CEN→DMN] × bands[gamma] 0.059      0.040      7.633      0.160      [-0.020, 0.138]     , q = 0.595
# network_relation[CEN→SN] × bands[gamma] 0.059      0.063      5.104      0.380      [-0.064, 0.182]     , q = 0.810
# network_relation[DMN→CEN] × bands[gamma] -0.067     0.027      -8.732     0.021   *  [-0.121, -0.014]    , q = 0.565
# network_relation[DMN→DMN] × bands[gamma] 0.016      0.021      1.909      0.487      [-0.026, 0.057]     , q = 0.831
# network_relation[DMN→SN] × bands[gamma] 0.012      0.049      1.066      0.816      [-0.083, 0.107]     , q = 0.947
# network_relation[SN→CEN] × bands[gamma] -0.056     0.041      -4.860     0.189      [-0.136, 0.024]     , q = 0.595
# network_relation[SN→DMN] × bands[gamma] -0.002     0.032      -0.158     0.955      [-0.064, 0.060]     , q = 0.955
# network_relation[SN→SN] × bands[gamma] 0.024      0.030      1.183      0.457      [-0.034, 0.082]     , q = 0.831
#
# Significance codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Note: q is the Benjamini-Hochberg corrected p-value over this model's 45 coefficients (the Intercept is excluded from the family). 0 of 45 terms have q < 0.05.
#
# Note: All p-values, standard errors, and confidence intervals are permutation-based (permuted group).

# %%
# =============================================================================
# 5. Regression Analysis: full specification with interactions
# =============================================================================
print("\n" + "=" * 80)
print("5. Regression Analysis: full specification with interactions")
print("=" * 80)

results_full_merged = study.regression(
    "~ city + eyes +network_relation:bands",
    add_network_categories=True,
    n_permutations=10000,
    band_order=FREQUENCY_BAND_ORDER
)

results_full_unmerged = study2.regression(
    "~ city + eyes +network_relation:bands",
    add_network_categories=True,
    n_permutations=10000,
    band_order=FREQUENCY_BAND_ORDER
)

print(study.print_apa_format(results_full_merged))
print(study2.print_apa_format(results_full_unmerged))
# Out:
# ================================================================================
# 5. Regression Analysis: full specification with interactions
# ================================================================================
# Calculating permutation-based statistics...
# Calculating permutation-based statistics...
# Regression Analysis Results (APA Format)
# ----------------------------------------
# Model: contrast ~ city + eyes +network_relation:bands
#
# The regression model explained 0.164 of the variance, F = 19.904, p = 0.199
# Note: p-values are permutation-based (permuted group)
#
# Contrast Statistics:
# Mean Contrast: 0.022, 95% CI [-0.034, 0.034], p = 0.215
# Median Contrast: 0.020, 95% CI [-0.036, 0.037], p = 0.290
#
# Regression Coefficients:
# Parameter            Estimate   SE         t          p
# -------------------- ---------- ---------- ---------- ----------
# Intercept            -0.006     0.025      -0.771     0.816      [-0.055, 0.043]
# eyes open            -0.010     0.011      -3.505     0.395      [-0.032, 0.012]     , q = 0.846
# theta                0.022      0.056      1.892      0.719      [-0.088, 0.132]     , q = 0.873
# alpha                0.048      0.055      4.201      0.408      [-0.059, 0.156]     , q = 0.846
# beta                 0.030      0.049      2.611      0.570      [-0.066, 0.126]     , q = 0.870
# gamma                0.015      0.044      1.318      0.751      [-0.071, 0.101]     , q = 0.873
# CEN→DMN × bands[delta] 0.040      0.022      3.607      0.075   .  [-0.003, 0.084]     , q = 0.422
# CEN→SN × bands[delta] 0.068      0.043      4.809      0.126      [-0.016, 0.152]     , q = 0.567
# DMN→CEN × bands[delta] -0.042     0.022      -3.746     0.071   .  [-0.086, 0.002]     , q = 0.422
# DMN→DMN × bands[delta] 0.015      0.016      1.264      0.381      [-0.016, 0.045]     , q = 0.846
# DMN→SN × bands[delta] 0.034      0.034      2.405      0.350      [-0.033, 0.101]     , q = 0.846
# SN→CEN × bands[delta] -0.020     0.036      -1.388     0.619      [-0.091, 0.052]     , q = 0.870
# SN→DMN × bands[delta] -0.016     0.028      -1.159     0.589      [-0.070, 0.038]     , q = 0.870
# SN→SN × bands[delta] 0.006      0.027      0.286      0.831      [-0.047, 0.059]     , q = 0.873
# CEN→DMN × bands[theta] 0.056      0.021      5.000      0.012   *  [0.014, 0.098]      , q = 0.133
# CEN→SN × bands[theta] 0.073      0.035      5.166      0.042   *  [0.004, 0.142]      , q = 0.312
# DMN→CEN × bands[theta] -0.040     0.027      -3.573     0.154      [-0.093, 0.013]     , q = 0.577
# DMN→DMN × bands[theta] 0.004      0.022      0.333      0.871      [-0.040, 0.047]     , q = 0.891
# DMN→SN × bands[theta] 0.026      0.029      1.809      0.414      [-0.032, 0.083]     , q = 0.846
# SN→CEN × bands[theta] -0.026     0.054      -1.854     0.652      [-0.132, 0.079]     , q = 0.873
# SN→DMN × bands[theta] 0.010      0.044      0.741      0.834      [-0.076, 0.097]     , q = 0.873
# SN→SN × bands[theta] 0.037      0.039      1.692      0.378      [-0.040, 0.113]     , q = 0.846
# CEN→DMN × bands[alpha] 0.068      0.022      6.080      0.003   ** [0.024, 0.112]      , q = 0.110
# CEN→SN × bands[alpha] 0.056      0.036      3.971      0.139      [-0.015, 0.127]     , q = 0.567
# DMN→CEN × bands[alpha] -0.021     0.026      -1.840     0.451      [-0.071, 0.030]     , q = 0.870
# DMN→DMN × bands[alpha] 0.030      0.028      2.615      0.309      [-0.025, 0.085]     , q = 0.846
# DMN→SN × bands[alpha] 0.024      0.034      1.700      0.508      [-0.042, 0.090]     , q = 0.870
# SN→CEN × bands[alpha] -0.044     0.057      -3.126     0.468      [-0.155, 0.067]     , q = 0.870
# SN→DMN × bands[alpha] 0.014      0.051      0.996      0.802      [-0.086, 0.114]     , q = 0.873
# SN→SN × bands[alpha] -0.011     0.047      -0.495     0.830      [-0.102, 0.081]     , q = 0.873
# CEN→DMN × bands[beta] 0.070      0.024      6.212      0.005   ** [0.022, 0.117]      , q = 0.110
# CEN→SN × bands[beta] 0.078      0.044      5.530      0.084   .  [-0.008, 0.164]     , q = 0.422
# DMN→CEN × bands[beta] -0.036     0.028      -3.188     0.227      [-0.090, 0.019]     , q = 0.787
# DMN→DMN × bands[beta] 0.013      0.023      1.164      0.594      [-0.032, 0.059]     , q = 0.870
# DMN→SN × bands[beta] 0.009      0.034      0.620      0.810      [-0.058, 0.076]     , q = 0.873
# SN→CEN × bands[beta] -0.022     0.057      -1.576     0.728      [-0.134, 0.090]     , q = 0.873
# SN→DMN × bands[beta] 0.019      0.047      1.367      0.714      [-0.072, 0.111]     , q = 0.873
# SN→SN × bands[beta]  0.024      0.044      1.113      0.611      [-0.063, 0.111]     , q = 0.870
# CEN→DMN × bands[gamma] 0.055      0.024      4.906      0.025   *  [0.008, 0.102]      , q = 0.221
# CEN→SN × bands[gamma] 0.055      0.047      3.905      0.270      [-0.037, 0.148]     , q = 0.826
# DMN→CEN × bands[gamma] -0.071     0.028      -6.334     0.011   *  [-0.125, -0.017]    , q = 0.133
# DMN→DMN × bands[gamma] 0.012      0.018      1.024      0.529      [-0.023, 0.046]     , q = 0.870
# DMN→SN × bands[gamma] 0.009      0.036      0.604      0.833      [-0.063, 0.080]     , q = 0.873
# SN→CEN × bands[gamma] -0.060     0.052      -4.240     0.275      [-0.162, 0.043]     , q = 0.826
# SN→DMN × bands[gamma] -0.006     0.041      -0.397     0.906      [-0.087, 0.075]     , q = 0.906
# SN→SN × bands[gamma] 0.020      0.028      0.921      0.515      [-0.036, 0.076]     , q = 0.870
#
# Significance codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Note: q is the Benjamini-Hochberg corrected p-value over this model's 45 coefficients (the Intercept is excluded from the family). 0 of 45 terms have q < 0.05.
#
# Note: All p-values, standard errors, and confidence intervals are permutation-based (permuted group).
# Regression Analysis Results (APA Format)
# ----------------------------------------
# Model: contrast ~ city + eyes +network_relation:bands
#
# The regression model explained 0.057 of the variance, F = 12.050, p = 0.320
# Note: p-values are permutation-based (permuted group)
#
# Contrast Statistics:
# Mean Contrast: 0.023, 95% CI [-0.034, 0.034], p = 0.188
# Median Contrast: 0.020, 95% CI [-0.034, 0.035], p = 0.265
#
# Regression Coefficients:
# Parameter            Estimate   SE         t          p
# -------------------- ---------- ---------- ---------- ----------
# Intercept            0.012      0.025      1.200      0.685      [-0.038, 0.061]
# Warszawa             -0.019     0.035      -5.533     0.640      [-0.087, 0.049]     , q = 0.893
# eyes open            -0.009     0.011      -2.722     0.478      [-0.031, 0.013]     , q = 0.845
# theta                -0.000     0.023      -0.004     0.998      [-0.046, 0.045]     , q = 0.998
# alpha                0.036      0.040      2.652      0.429      [-0.042, 0.113]     , q = 0.789
# beta                 0.014      0.031      1.063      0.683      [-0.046, 0.075]     , q = 0.923
# gamma                0.002      0.027      0.140      0.952      [-0.052, 0.055]     , q = 0.986
# CEN→DMN × bands[delta] 0.040      0.019      3.063      0.064   .  [0.003, 0.078]      , q = 0.494
# CEN→SN × bands[delta] 0.050      0.029      3.020      0.128      [-0.006, 0.106]     , q = 0.590
# DMN→CEN × bands[delta] -0.037     0.020      -2.790     0.118      [-0.077, 0.003]     , q = 0.590
# DMN→DMN × bands[delta] 0.018      0.016      1.341      0.326      [-0.014, 0.050]     , q = 0.761
# DMN→SN × bands[delta] 0.020      0.031      1.215      0.576      [-0.041, 0.081]     , q = 0.883
# SN→CEN × bands[delta] -0.006     0.023      -0.373     0.814      [-0.051, 0.039]     , q = 0.972
# SN→DMN × bands[delta] -0.003     0.023      -0.181     0.909      [-0.049, 0.043]     , q = 0.972
# SN→SN × bands[delta] 0.005      0.028      0.210      0.871      [-0.049, 0.060]     , q = 0.972
# CEN→DMN × bands[theta] 0.063      0.022      4.768      0.013   *  [0.019, 0.106]      , q = 0.196
# CEN→SN × bands[theta] 0.067      0.033      4.026      0.076   .  [0.002, 0.131]      , q = 0.497
# DMN→CEN × bands[theta] -0.031     0.023      -2.371     0.225      [-0.075, 0.013]     , q = 0.754
# DMN→DMN × bands[theta] 0.013      0.021      0.950      0.602      [-0.029, 0.054]     , q = 0.885
# DMN→SN × bands[theta] 0.035      0.035      2.089      0.390      [-0.034, 0.104]     , q = 0.769
# SN→CEN × bands[theta] -0.004     0.026      -0.241     0.892      [-0.055, 0.047]     , q = 0.972
# SN→DMN × bands[theta] 0.027      0.027      1.625      0.391      [-0.027, 0.080]     , q = 0.769
# SN→SN × bands[theta] 0.034      0.035      1.328      0.401      [-0.034, 0.101]     , q = 0.769
# CEN→DMN × bands[alpha] 0.068      0.022      5.182      0.006   ** [0.025, 0.111]      , q = 0.133
# CEN→SN × bands[alpha] 0.040      0.031      2.445      0.250      [-0.020, 0.101]     , q = 0.754
# DMN→CEN × bands[alpha] -0.015     0.021      -1.132     0.536      [-0.056, 0.026]     , q = 0.850
# DMN→DMN × bands[alpha] 0.036      0.026      2.648      0.234      [-0.016, 0.087]     , q = 0.754
# DMN→SN × bands[alpha] 0.027      0.037      1.633      0.522      [-0.045, 0.099]     , q = 0.850
# SN→CEN × bands[alpha] -0.021     0.028      -1.239     0.525      [-0.076, 0.035]     , q = 0.850
# SN→DMN × bands[alpha] 0.037      0.033      2.247      0.331      [-0.028, 0.102]     , q = 0.761
# SN→SN × bands[alpha] -0.002     0.035      -0.071     0.964      [-0.071, 0.067]     , q = 0.986
# CEN→DMN × bands[beta] 0.075      0.022      5.678      0.003   ** [0.031, 0.119]      , q = 0.133
# CEN→SN × bands[beta] 0.066      0.037      3.993      0.113      [-0.006, 0.138]     , q = 0.590
# DMN→CEN × bands[beta] -0.027     0.024      -2.093     0.324      [-0.075, 0.020]     , q = 0.761
# DMN→DMN × bands[beta] 0.029      0.022      2.136      0.262      [-0.015, 0.073]     , q = 0.754
# DMN→SN × bands[beta] 0.014      0.039      0.839      0.756      [-0.062, 0.090]     , q = 0.972
# SN→CEN × bands[beta] -0.004     0.029      -0.266     0.896      [-0.060, 0.051]     , q = 0.972
# SN→DMN × bands[beta] 0.034      0.031      2.060      0.330      [-0.026, 0.094]     , q = 0.761
# SN→SN × bands[beta]  0.012      0.041      0.471      0.806      [-0.069, 0.093]     , q = 0.972
# CEN→DMN × bands[gamma] 0.054      0.021      4.123      0.027   *  [0.012, 0.096]      , q = 0.247
# CEN→SN × bands[gamma] 0.035      0.034      2.136      0.362      [-0.031, 0.102]     , q = 0.769
# DMN→CEN × bands[gamma] -0.062     0.024      -4.751     0.021   *  [-0.109, -0.016]    , q = 0.239
# DMN→DMN × bands[gamma] 0.024      0.018      1.774      0.253      [-0.012, 0.060]     , q = 0.754
# DMN→SN × bands[gamma] 0.006      0.038      0.378      0.886      [-0.068, 0.081]     , q = 0.972
# SN→CEN × bands[gamma] -0.041     0.029      -2.492     0.223      [-0.099, 0.016]     , q = 0.754
# SN→DMN × bands[gamma] 0.009      0.032      0.548      0.803      [-0.053, 0.071]     , q = 0.972
# SN→SN × bands[gamma] 0.017      0.029      0.665      0.616      [-0.040, 0.074]     , q = 0.885
#
# Significance codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Note: q is the Benjamini-Hochberg corrected p-value over this model's 46 coefficients (the Intercept is excluded from the family). 0 of 46 terms have q < 0.05.
#
# Note: All p-values, standard errors, and confidence intervals are permutation-based (permuted group).

# %%
# =============================================================================
# 6. Specification Curve Analysis
#
# Rendered inline for inspection. The manuscript's Figure 4 comes from
# figures/scripts/07_spec_curve_ridgeline.py, which draws the same renderer but
# from the committed spec_cache_*.csv (about 1 MB) rather than the .cdb caches,
# prettifies the factor labels, and writes pdf/png/svg. Prefer that script when
# regenerating the figure; use the cells here when exploring.
# =============================================================================
print("\n" + "=" * 80)
print("6. Specification Curve Analysis")
print("=" * 80)

print("Specification curve for model1 with merged data...")
spec_df, results_df = study.specification_curve(add_network_categories=True, plot_type='density')

print("Specification curve for model2 with unmerged data...")
spec_df, results_df = study2.specification_curve(add_network_categories=True, plot_type='density')
# Out:
# ================================================================================
# 6. Specification Curve Analysis
# ================================================================================
# Specification curve for model1 with merged data...
# Specification curve for model2 with unmerged data...

# %%
# =============================================================================
# 7. P-Value Histograms
#
# Kept as the exploratory view. The manuscript's Figure S10 is an ECDF against a
# Kolmogorov-Smirnov acceptance band, from figures/scripts/06_figureS10_pvalues.py:
# with 9 parameters spread over 40 bins the expected count per bin is 0.22, so a
# histogram cannot show whether the permutation p-values are uniform.
# =============================================================================
print("\n" + "=" * 80)
print("7. P-Value Histograms")
print("=" * 80)

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

models = [
    (results_network_only, "Model 1"),
    (results_network_bands, "Model 2"),
    (results_full_merged, "Model 3"),
    (results_full_unmerged, "Model 4"),
]

for ax, (results, title) in zip(axes.flat, models):
    n_pvalues, n_sig = plot_pvalue_histogram(ax, results, title)
    if n_pvalues > 0:
        print(f"{title}: {n_pvalues} parameters, {n_sig} significant at α=0.05")

# Shared labels
fig.supxlabel('p-value (permutation-based)', fontsize=14)
fig.supylabel('Relative Frequency', fontsize=14)

# Shared legend
handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', fontsize=12)

plt.tight_layout()
plt.subplots_adjust(top=0.92)
plt.show()
# Out:
# ================================================================================
# 7. P-Value Histograms
# ================================================================================
# Model 1: 9 parameters, 1 significant at α=0.05
# Model 2: 45 parameters, 3 significant at α=0.05
# Model 3: 46 parameters, 6 significant at α=0.05
# Model 4: 47 parameters, 5 significant at α=0.05
